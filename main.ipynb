# %% [markdown]
# # Neural clustering

# %%
from train import train
from model import Clusterizer
import utils
from utils import use_cuda, visualize_cluster_assignment

# %%
from torch.utils.data import DataLoader

# %% [markdown]
# ### Gaussian Mixture Experiments

# %%
from utils import generate_gaussian_mixture_dataset

# %%
input_size = 100
batch_size = 32
n_clusters = 4
dataset_size = 10000

# %% [markdown]
# ##### Generating dataset

# %%
dataset, means, covs = generate_gaussian_mixture_dataset(input_size=input_size,
                                                         n_clusters=n_clusters,
                                                         dataset_size=dataset_size)

dataloader = {x: DataLoader(dataset[x], batch_size=batch_size, shuffle=True) for x in dataset.keys()}

# %% [markdown]
# ##### Creating and training the model until convergence

# %%
model = Clusterizer(input_size=input_size, n_clusters=n_clusters)
loss = train(model, dataloader)
# Out:
# Epoch : 0 ----- Loss : 555.68
# Epoch : 1 ----- Loss : 139.72
# Epoch : 2 ----- Loss : 110.93
# Epoch : 3 ----- Loss : 110.78
# Epoch : 4 ----- Loss : 110.48
# Epoch : 5 ----- Loss : 110.31
# Epoch : 6 ----- Loss : 110.17
# Epoch : 7 ----- Loss : 109.68
# Epoch : 8 ----- Loss : 109.23
# Epoch : 9 ----- Loss : 108.82
# Epoch : 10 ----- Loss : 108.57
# Epoch : 11 ----- Loss : 108.45
# Epoch : 12 ----- Loss : 108.35
# Epoch : 13 ----- Loss : 108.31
# Epoch : 14 ----- Loss : 108.26
# Epoch : 15 ----- Loss : 108.17
# Epoch : 16 ----- Loss : 108.09
# Epoch : 17 ----- Loss : 108.02
# Epoch : 18 ----- Loss : 107.91
# Epoch : 19 ----- Loss : 107.79
# Epoch : 20 ----- Loss : 107.52
# Epoch : 21 ----- Loss : 107.27
# Epoch : 22 ----- Loss : 107.03
# Epoch : 23 ----- Loss : 106.76
# Epoch : 24 ----- Loss : 106.53
# Epoch : 25 ----- Loss : 106.29
# Epoch : 26 ----- Loss : 106.09
# Epoch : 27 ----- Loss : 105.89
# Epoch : 28 ----- Loss : 105.65
# Epoch : 29 ----- Loss : 105.47
# Epoch : 30 ----- Loss : 105.26
# Epoch : 31 ----- Loss : 105.06
# Epoch : 32 ----- Loss : 104.85
# Epoch : 33 ----- Loss : 104.69
# Epoch : 34 ----- Loss : 104.51
# Epoch : 35 ----- Loss : 104.38
# Epoch : 36 ----- Loss : 104.18
# Epoch : 37 ----- Loss : 104.01
# Epoch : 38 ----- Loss : 103.87
# Epoch : 39 ----- Loss : 103.66
# Epoch : 40 ----- Loss : 103.54
# Epoch : 41 ----- Loss : 103.40
# Epoch : 42 ----- Loss : 103.30
# Epoch : 43 ----- Loss : 103.13
# Epoch : 44 ----- Loss : 102.98
# Epoch : 45 ----- Loss : 102.85
# Epoch : 46 ----- Loss : 102.74
# Epoch : 47 ----- Loss : 102.65
# Epoch : 48 ----- Loss : 102.50
# Epoch : 49 ----- Loss : 102.40
# Epoch : 50 ----- Loss : 102.23
# Epoch : 51 ----- Loss : 102.16
# Epoch : 52 ----- Loss : 102.05
# Epoch : 53 ----- Loss : 101.93
# Epoch : 54 ----- Loss : 101.82
# Epoch : 55 ----- Loss : 101.70
# Epoch : 56 ----- Loss : 101.59
# Epoch : 57 ----- Loss : 101.52
# Epoch : 58 ----- Loss : 101.40
# Epoch : 59 ----- Loss : 101.29
# Epoch : 60 ----- Loss : 101.19
# Epoch : 61 ----- Loss : 101.08
# Epoch : 62 ----- Loss : 101.01
# Epoch : 63 ----- Loss : 100.87
# Epoch : 64 ----- Loss : 100.79
# Epoch : 65 ----- Loss : 100.66
# Epoch : 66 ----- Loss : 100.62
# Epoch : 67 ----- Loss : 100.51
# Epoch : 68 ----- Loss : 100.43
# Epoch : 69 ----- Loss : 100.29
# Epoch : 70 ----- Loss : 100.28
# Epoch : 71 ----- Loss : 100.17
# Epoch : 72 ----- Loss : 100.07
# Epoch : 73 ----- Loss : 99.98
# Epoch : 74 ----- Loss : 99.96
# Epoch : 75 ----- Loss : 99.84
# Epoch : 76 ----- Loss : 99.79
# Epoch : 77 ----- Loss : 99.73
# Epoch : 78 ----- Loss : 99.62
# Epoch : 79 ----- Loss : 99.58
# Epoch : 80 ----- Loss : 99.48
# Epoch : 81 ----- Loss : 99.40
# Epoch : 82 ----- Loss : 99.34
# Epoch : 83 ----- Loss : 99.27
# Epoch : 84 ----- Loss : 99.22
# Epoch : 85 ----- Loss : 99.12
# Epoch : 86 ----- Loss : 99.09
# Epoch : 87 ----- Loss : 99.01
# Epoch : 88 ----- Loss : 98.94
# Epoch : 89 ----- Loss : 98.90
# Epoch : 90 ----- Loss : 98.83
# Epoch : 91 ----- Loss : 98.74
# Epoch : 92 ----- Loss : 98.70
# Epoch : 93 ----- Loss : 98.62
# Epoch : 94 ----- Loss : 98.57
# Epoch : 95 ----- Loss : 98.50
# Epoch : 96 ----- Loss : 98.49
# Epoch : 97 ----- Loss : 98.38
# Epoch : 98 ----- Loss : 98.35
# Epoch : 99 ----- Loss : 98.29
# Epoch : 100 ----- Loss : 98.24
# Epoch : 101 ----- Loss : 98.20
# Epoch : 102 ----- Loss : 98.12
# Epoch : 103 ----- Loss : 98.08
# Epoch : 104 ----- Loss : 98.05
# Epoch : 105 ----- Loss : 97.97
# Epoch : 106 ----- Loss : 97.93
# Epoch : 107 ----- Loss : 97.90
# Epoch : 108 ----- Loss : 97.85
# Epoch : 109 ----- Loss : 97.79
# Epoch : 110 ----- Loss : 97.76
# Epoch : 111 ----- Loss : 97.68
# Epoch : 112 ----- Loss : 97.66
# Epoch : 113 ----- Loss : 97.61
# Epoch : 114 ----- Loss : 97.54
# Epoch : 115 ----- Loss : 97.56

# %% [markdown]
# ##### Visualizing results
# Here, we project the data in 2 dimensions

# %%
visualize_cluster_assignment(model, dataset, show=True)

# %% [markdown]
# ### Two Moons Experiments

# %%
from utils import generate_two_moons_dataset

# %%
input_size = 2
batch_size = 32
n_clusters = 2
dataset_size = 10000

# %% [markdown]
# ##### Generating dataset

# %%
dataset = generate_two_moons_dataset(dataset_size)
dataloader = {x: DataLoader(dataset[x], batch_size=batch_size, shuffle=True) for x in dataset.keys()}

# %% [markdown]
# ##### Creating and training the model until convergence

# %%
model = Clusterizer(input_size=input_size, n_clusters=n_clusters)
loss = train(model, dataloader)
# Out:
# Epoch : 0 ----- Loss : 24.87
# Epoch : 1 ----- Loss : 8.14
# Epoch : 2 ----- Loss : 5.90
# Epoch : 3 ----- Loss : 4.19
# Epoch : 4 ----- Loss : 3.48
# Epoch : 5 ----- Loss : 3.16
# Epoch : 6 ----- Loss : 2.98
# Epoch : 7 ----- Loss : 2.82
# Epoch : 8 ----- Loss : 2.67
# Epoch : 9 ----- Loss : 2.54
# Epoch : 10 ----- Loss : 2.40
# Epoch : 11 ----- Loss : 2.27
# Epoch : 12 ----- Loss : 2.14
# Epoch : 13 ----- Loss : 2.00
# Epoch : 14 ----- Loss : 1.86
# Epoch : 15 ----- Loss : 1.73
# Epoch : 16 ----- Loss : 1.57
# Epoch : 17 ----- Loss : 1.43
# Epoch : 18 ----- Loss : 1.30
# Epoch : 19 ----- Loss : 1.19
# Epoch : 20 ----- Loss : 1.08
# Epoch : 21 ----- Loss : 0.98
# Epoch : 22 ----- Loss : 0.90
# Epoch : 23 ----- Loss : 0.82
# Epoch : 24 ----- Loss : 0.77
# Epoch : 25 ----- Loss : 0.72
# Epoch : 26 ----- Loss : 0.68
# Epoch : 27 ----- Loss : 0.63
# Epoch : 28 ----- Loss : 0.60
# Epoch : 29 ----- Loss : 0.57
# Epoch : 30 ----- Loss : 0.54
# Epoch : 31 ----- Loss : 0.53
# Epoch : 32 ----- Loss : 0.51
# Epoch : 33 ----- Loss : 0.47
# Epoch : 34 ----- Loss : 0.46
# Epoch : 35 ----- Loss : 0.45
# Epoch : 36 ----- Loss : 0.42
# Epoch : 37 ----- Loss : 0.42
# Epoch : 38 ----- Loss : 0.40
# Epoch : 39 ----- Loss : 0.38
# Epoch : 40 ----- Loss : 0.39

# %% [markdown]
# ##### Visualizing results

# %%
visualize_cluster_assignment(model, dataset, show=True)
